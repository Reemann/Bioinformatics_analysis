# %% [markdown]
# ## histogram

# %%
with sns.axes_style('white', rc={
        'xtick.bottom': True,
        'ytick.left': True
}), sns.plotting_context('paper',
                         rc={
                             'axes.titlesize': 14,
                             'axes.labelsize': 12,
                             'xtick.labelsize': 10,
                             'ytick.labelsize': 10,
                             'legend.fontsize': 10
                         }):
    fig, axes = plt.subplots(figsize = (4,4), tight_layout = True)
    plot_df = genome_bin_tf_mtl.copy()
    tf_num = genome_bin_tf_mtl.iloc[:,4:].sum(1).tolist()
    plot_df.loc[:,'TF_num'] = tf_num
    h = sns.histplot(data = plot_df, 
                 x = 'TF_num', 
                 ax = axes, 
                 bins = [x/10 for x in range(35, 205, 10)],
                 color = '#90ADC6')
#     axes.set_yscale('log')
    axes.set_xlim(3.4,17.6)
    axes.set_ylim(0, 1200)
    
    s = 0
    for p in h.patches:
        s+= p.get_height()
    for p in h.patches :
        if p.get_height() != 0 :
            axes.text(p.get_x() + p.get_width()/2.,
                    p.get_height(),
                    '{}'.format(int(p.get_height())), 
                    fontsize=10,
                    color='black',
                    ha='center',
                    va='bottom')
    
#     axes[i].set_title(f'{title_dict[condition]} v.s. WT')
    axes.set_xticks(range(4,18))
    axes.set_xlabel('Number of TFs')
    axes.set_ylabel('Number of MTLs')
    fig.savefig('/mnt/Storage/home/wangyiman/early_embryo_network/figures/make7_histplot_MTL_TFnum.pdf',
                transparent=True)

# %%
plot_df
# Out:
#           chr     start       end            name  Ctcf  Eomesa  Foxh1  Gmeb1  \
# 169      chr1    214000    215000    bin_chr1_214     0       0      0      0
# 492      chr1    605000    606000    bin_chr1_605     2       0      0      0
# 557      chr1    682000    683000    bin_chr1_682     1       0      0      0
# 657      chr1    797000    798000    bin_chr1_797     1       0      0      0
# 706      chr1    849000    850000    bin_chr1_849     1       0      0      0
# ...       ...       ...       ...             ...   ...     ...    ...    ...
# 1219250  chr9  53097000  53098000  bin_chr9_53097     0       0      1      0
# 1219773  chr9  53668000  53669000  bin_chr9_53668     0       1      1      1
# 1220652  chr9  54619000  54620000  bin_chr9_54619     1       0      0      0
# 1221122  chr9  55134000  55135000  bin_chr9_55134     0       0      0      1
# 1221161  chr9  55182000  55183000  bin_chr9_55182     0       0      0      0
#
# ...

# %%
genome_bin_tf_mtl
# Out:
#           chr     start       end            name  Ctcf  Eomesa  Foxh1  Gmeb1  \
# 169      chr1    214000    215000    bin_chr1_214     0       0      0      0
# 492      chr1    605000    606000    bin_chr1_605     2       0      0      0
# 557      chr1    682000    683000    bin_chr1_682     1       0      0      0
# 657      chr1    797000    798000    bin_chr1_797     1       0      0      0
# 706      chr1    849000    850000    bin_chr1_849     1       0      0      0
# ...       ...       ...       ...             ...   ...     ...    ...    ...
# 1219250  chr9  53097000  53098000  bin_chr9_53097     0       0      1      0
# 1219773  chr9  53668000  53669000  bin_chr9_53668     0       1      1      1
# 1220652  chr9  54619000  54620000  bin_chr9_54619     1       0      0      0
# 1221122  chr9  55134000  55135000  bin_chr9_55134     0       0      0      1
# 1221161  chr9  55182000  55183000  bin_chr9_55182     0       0      0      0
#
# ...
